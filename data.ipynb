# %%
import nibabel as nib
import numpy as np
import matplotlib.pyplot as plt

# %%
img_path = './data/0.nii'
mask_path = './data/0-sample.nii'
images = nib.load(img_path)
masks = nib.load(mask_path)

# %%
images.shape, masks.shape
# Out:
# ((1008, 1008, 95), (1008, 1008, 95))

# %%
images.affine.shape, masks.affine.shape
# Out:
# ((4, 4), (4, 4))

# %%
header = images.header
header.get_xyzt_units()
header.structarr
# Out:
# array((348, b'', b'', 0, 0, b'', 0, [   3, 1008, 1008,   95,    1,    1,    1,    1], 0., 0., 0., 0, 4, 16, 0, [1.        , 0.12076741, 0.12076741, 0.12076741, 1.        , 1.        , 1.        , 1.        ], 0., nan, nan, 0, 0, 0, 0., 0., 0., 0., 0, 0, b'', b'', 0, 2, 0., 0., 0., 0., 0., 0., [0.12076741, 0.        , 0.        , 0.        ], [0.        , 0.12076741, 0.        , 0.        ], [0.        , 0.        , 0.12076741, 0.        ], b'', b'n+1'),
# ...

# %%
test_image=images.get_data()
test_mask=masks.get_data()
fig, (ax1, ax2) = plt.subplots(1,2, figsize = (12, 6))
ax1.imshow(test_image[:,60,:])
ax1.set_title('Image')
ax2.imshow(test_mask[:,0,:])
ax2.set_title('Mask')
# Out:
# c:\users\maste\git\ct-segmentation\venv\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   """Entry point for launching an IPython kernel.
# c:\users\maste\git\ct-segmentation\venv\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
# Text(0.5, 1.0, 'Mask')

# %%
np.unique(test_mask), np.unique(test_image)
# Out:
# (array([0, 1, 2, 3, 4], dtype=uint16),
#  array([-32768, -32767, -32766, ...,   8146,   8243,   8757], dtype=int16))

# %%
slice = images.get_data()[:, :, 3]
# Out:
# c:\users\maste\git\ct-segmentation\venv\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   """Entry point for launching an IPython kernel.

# %%
slice.shape
# Out:
# (1008, 1008)

# %%
import cv2

#%

# %%
slice = images.get_data()[:, :, 1]
cv2.imwrite('test.png', slice)
# Out:
# c:\users\maste\git\ct-segmentation\venv\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   """Entry point for launching an IPython kernel.
# True

# %%
img_uint = np.zeros(slice.shape)
img_uint = cv2.normalize(slice, img_uint, 0, 255, cv2.NORM_MINMAX)
print(np.max(img_uint))
# Out:
# 0
